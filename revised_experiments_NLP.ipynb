# %%
lines = open('cricketbat.txt').read()

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(lines)
tokens = [token.lower() for token in tokens]

# %%
BAD_CHARS = [';', ':', '!', "*", '<', '>','#','?','@','p',',','.','(',')']
no_bad_chars = list(filter(lambda token: token not in BAD_CHARS, tokens))

# %%
from nltk.corpus import stopwords

STOP_WORDS = set(stopwords.words('english'))
no_stop_words = list(filter(lambda token: token not in STOP_WORDS, no_bad_chars))

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from tabulate import tabulate

stemmer = PorterStemmer()
stem = [stemmer.stem(token) for token in no_stop_words]


lemmatizer = WordNetLemmatizer()
lemma = [lemmatizer.lemmatize(token) for token in no_stop_words]

print(tabulate(zip(no_stop_words, stem, lemma), headers=['WORD', 'STEM', 'LEMMA']))
# Out:
# WORD              STEM              LEMMA
# ----------------  ----------------  ----------------
# blade             blade             blade
# cricket           cricket           cricket
# bat               bat               bat
# wooden            wooden            wooden
# block             block             block
# generally         gener             generally
# flat              flat              flat
# striking          strike            striking
# face              face              face
# ridge             ridg              ridge
# reverse           revers            reverse
# back              back              back
# concentrates      concentr          concentrate
# wood              wood              wood
# middle            middl             middle
# ball              ball              ball
# generally         gener             generally
# hit               hit               hit
# bat               bat               bat
# traditionally     tradit            traditionally
# made              made              made
# willow            willow            willow
# wood              wood              wood
# specifically      specif            specifically
# variety           varieti           variety
# white             white             white
# willow            willow            willow
# called            call              called
# cricket           cricket           cricket
# bat               bat               bat
# willow            willow            willow
# salix             salix             salix
# alba              alba              alba
# var               var               var
# caerulea          caerulea          caerulea
# treated           treat             treated
# raw               raw               raw
# unboiled          unboil            unboiled
# linseed           linse             linseed
# oil               oil               oil
# protective        protect           protective
# function          function          function
# variety           varieti           variety
# willow            willow            willow
# used              use               used
# tough             tough             tough
# shock-resistant   shock-resist      shock-resistant
# significantly     significantli     significantly
# dented            dent              dented
# splintering       splinter          splintering
# impact            impact            impact
# cricket           cricket           cricket
# ball              ball              ball
# high              high              high
# speed             speed             speed
# also              also              also
# light             light             light
# weight            weight            weight
# face              face              face
# bat               bat               bat
# often             often             often
# covered           cover             covered
# protective        protect           protective
# film              film              film
# user              user              user
# blade             blade             blade
# connected         connect           connected
# long              long              long
# cylindrical       cylindr           cylindrical
# cane              cane              cane
# handle            handl             handle
# similar           similar           similar
# mid-20th-century  mid-20th-centuri  mid-20th-century
# tennis            tenni             tennis
# racquet           racquet           racquet
# means             mean              mean
# splice            splice            splice
# handle            handl             handle
# usually           usual             usually
# covered           cover             covered
# rubber            rubber            rubber
# grip              grip              grip
# bats              bat               bat
# incorporate       incorpor          incorporate
# wooden            wooden            wooden
# spring            spring            spring
# design            design            design
# handle            handl             handle
# meets             meet              meet
# blade             blade             blade
# current           current           current
# design            design            design
# cane              cane              cane
# handle            handl             handle
# spliced           splice            spliced
# willow            willow            willow
# blade             blade             blade
# tapered           taper             tapered
# splice            splice            splice
# invention         invent            invention
# 1880s             1880              1880s
# charles           charl             charles
# richardson        richardson        richardson
# pupil             pupil             pupil
# brunel            brunel            brunel
# first             first             first
# chief             chief             chief
# engineer          engin             engineer
# severn            severn            severn
# railway           railway           railway
# tunnel            tunnel            tunnel
# spliced           splice            spliced
# handles           handl             handle
# used              use               used
# tended            tend              tended
# break             break             break
# corner            corner            corner
# join              join              join
# taper             taper             taper
# provides          provid            provides
# gradual           gradual           gradual
# transfer          transfer          transfer
# load              load              load
# bat               bat               bat
# 's                's                's
# blade             blade             blade
# handle            handl             handle
# avoids            avoid             avoids
# problem           problem           problem
# edges             edg               edge
# blade             blade             blade
# closest           closest           closest
# handle            handl             handle
# known             known             known
# shoulders         shoulder          shoulder
# bat               bat               bat
# bottom            bottom            bottom
# blade             blade             blade
# known             known             known
# toe               toe               toe
# bat               bat               bat
# bats              bat               bat
# always            alway             always
# shape             shape             shape
# 18th              18th              18th
# century           centuri           century
# bats              bat               bat
# tended            tend              tended
# shaped            shape             shaped
# similarly         similarli         similarly
# modern            modern            modern
# hockey            hockey            hockey
# sticks            stick             stick
# may               may               may
# well              well              well
# legacy            legaci            legacy
# game              game              game
# 's                's                's
# reputed           reput             reputed
# origins           origin            origin
# although          although          although
# first             first             first
# forms             form              form
# cricket           cricket           cricket
# obscure           obscur            obscure
# may               may               may
# game              game              game
# first             first             first
# played            play              played
# using             use               using
# shepherd          shepherd          shepherd
# 's                's                's
# crooks            crook             crook
# evolution         evolut            evolution
# cricket           cricket           cricket
# bat               bat               bat
# bat               bat               bat
# generally         gener             generally
# recognised        recognis          recognised
# oldest            oldest            oldest
# bat               bat               bat
# still             still             still
# existence         exist             existence
# dated             date              dated
# 1729              1729              1729
# display           display           display
# sandham           sandham           sandham
# room              room              room
# oval              oval              oval
# london            london            london
# cricket           cricket           cricket
# bat               bat               bat
# specialised       specialis         specialised
# piece             piec              piece
# equipment         equip             equipment
# used              use               used
# batsmen           batsmen           batsman
# sport             sport             sport
# cricket           cricket           cricket
# hit               hit               hit
# ball              ball              ball
# typically         typic             typically
# consisting        consist           consisting
# cane              cane              cane
# handle            handl             handle
# attached          attach            attached
# flat-fronted      flat-front        flat-fronted
# willow-wood       willow-wood       willow-wood
# blade             blade             blade
# length            length            length
# bat               bat               bat
# may               may               may
# 38                38                38
# inches            inch              inch
# 965               965               965
# mm                mm                mm
# width             width             width
# 4.25              4.25              4.25
# inches            inch              inch
# 108               108               108
# mm                mm                mm
# use               use               use
# first             first             first
# mentioned         mention           mentioned
# 1624              1624              1624

# %%
from nltk import pos_tag
pos_tags = list(pos_tag(no_stop_words))
word, tags = zip(*pos_tags)
print(tabulate(zip(no_stop_words, stem, lemma, tags), headers=['WORD', 'STEM', 'LEMMA', 'POS_TAG']))
# Out:
# WORD              STEM              LEMMA             POS_TAG
# ----------------  ----------------  ----------------  ---------
# blade             blade             blade             NN
# cricket           cricket           cricket           NN
# bat               bat               bat               NN
# wooden            wooden            wooden            NN
# block             block             block             NN
# generally         gener             generally         RB
# flat              flat              flat              JJ
# striking          strike            striking          VBG
# face              face              face              NN
# ridge             ridg              ridge             NN
# reverse           revers            reverse           VB
# back              back              back              RB
# concentrates      concentr          concentrate       VBZ
# wood              wood              wood              NN
# middle            middl             middle            NN
# ball              ball              ball              NN
# generally         gener             generally         RB
# hit               hit               hit               VBN
# bat               bat               bat               NN
# traditionally     tradit            traditionally     RB
# made              made              made              VBD
# willow            willow            willow            JJ
# wood              wood              wood              NN
# specifically      specif            specifically      RB
# variety           varieti           variety           VBZ
# white             white             white             JJ
# willow            willow            willow            NN
# called            call              called            VBN
# cricket           cricket           cricket           NN
# bat               bat               bat               NN
# willow            willow            willow            IN
# salix             salix             salix             NN
# alba              alba              alba              NN
# var               var               var               NN
# caerulea          caerulea          caerulea          NN
# treated           treat             treated           VBD
# raw               raw               raw               JJ
# unboiled          unboil            unboiled          JJ
# linseed           linse             linseed           NN
# oil               oil               oil               NN
# protective        protect           protective        JJ
# function          function          function          NN
# variety           varieti           variety           NN
# willow            willow            willow            NN
# used              use               used              VBN
# tough             tough             tough             JJ
# shock-resistant   shock-resist      shock-resistant   JJ
# significantly     significantli     significantly     RB
# dented            dent              dented            VBN
# splintering       splinter          splintering       VBG
# impact            impact            impact            NN
# cricket           cricket           cricket           NN
# ball              ball              ball              NN
# high              high              high              JJ
# speed             speed             speed             NN
# also              also              also              RB
# light             light             light             VBD
# weight            weight            weight            JJ
# face              face              face              NN
# bat               bat               bat               NN
# often             often             often             RB
# covered           cover             covered           VBD
# protective        protect           protective        JJ
# film              film              film              NN
# user              user              user              NN
# blade             blade             blade             NN
# connected         connect           connected         VBN
# long              long              long              RB
# cylindrical       cylindr           cylindrical       JJ
# cane              cane              cane              NN
# handle            handl             handle            VBD
# similar           similar           similar           JJ
# mid-20th-century  mid-20th-centuri  mid-20th-century  NN
# tennis            tenni             tennis            NN
# racquet           racquet           racquet           NN
# means             mean              mean              VBZ
# splice            splice            splice            JJ
# handle            handl             handle            NNS
# usually           usual             usually           RB
# covered           cover             covered           VBD
# rubber            rubber            rubber            JJ
# grip              grip              grip              NN
# bats              bat               bat               NNS
# incorporate       incorpor          incorporate       VBP
# wooden            wooden            wooden            JJ
# spring            spring            spring            NN
# design            design            design            NN
# handle            handl             handle            JJ
# meets             meet              meet              NNS
# blade             blade             blade             VBD
# current           current           current           JJ
# design            design            design            NN
# cane              cane              cane              NN
# handle            handl             handle            NN
# spliced           splice            spliced           VBD
# willow            willow            willow            JJ
# blade             blade             blade             NN
# tapered           taper             tapered           VBD
# splice            splice            splice            JJ
# invention         invent            invention         NN
# 1880s             1880              1880s             CD
# charles           charl             charles           NNS
# richardson        richardson        richardson        VBP
# pupil             pupil             pupil             JJ
# brunel            brunel            brunel            NN
# first             first             first             RB
# chief             chief             chief             JJ
# engineer          engin             engineer          NN
# severn            severn            severn            JJ
# railway           railway           railway           NN
# tunnel            tunnel            tunnel            NN
# spliced           splice            spliced           VBD
# handles           handl             handle            NNS
# used              use               used              VBN
# tended            tend              tended            VBD
# break             break             break             JJ
# corner            corner            corner            NN
# join              join              join              JJ
# taper             taper             taper             JJ
# provides          provid            provides          VBZ
# gradual           gradual           gradual           JJ
# transfer          transfer          transfer          NN
# load              load              load              NN
# bat               bat               bat               NN
# 's                's                's                POS
# blade             blade             blade             NN
# handle            handl             handle            NN
# avoids            avoid             avoids            NNS
# problem           problem           problem           NN
# edges             edg               edge              VBZ
# blade             blade             blade             VBN
# closest           closest           closest           JJS
# handle            handl             handle            NN
# known             known             known             VBN
# shoulders         shoulder          shoulder          NNS
# bat               bat               bat               VBP
# bottom            bottom            bottom            JJ
# blade             blade             blade             NN
# known             known             known             VBN
# toe               toe               toe               JJ
# bat               bat               bat               NN
# bats              bat               bat               NNS
# always            alway             always            RB
# shape             shape             shape             VBP
# 18th              18th              18th              JJ
# century           centuri           century           NN
# bats              bat               bat               NNS
# tended            tend              tended            VBD
# shaped            shape             shaped            VBD
# similarly         similarli         similarly         RB
# modern            modern            modern            JJ
# hockey            hockey            hockey            NN
# sticks            stick             stick             NNS
# may               may               may               MD
# well              well              well              RB
# legacy            legaci            legacy            VB
# game              game              game              NN
# 's                's                's                POS
# reputed           reput             reputed           JJ
# origins           origin            origin            NNS
# although          although          although          IN
# first             first             first             JJ
# forms             form              form              NNS
# cricket           cricket           cricket           VBP
# obscure           obscur            obscure           NN
# may               may               may               MD
# game              game              game              NN
# first             first             first             RB
# played            play              played            VBD
# using             use               using             VBG
# shepherd          shepherd          shepherd          NN
# 's                's                's                POS
# crooks            crook             crook             NNS
# evolution         evolut            evolution         VBP
# cricket           cricket           cricket           NN
# bat               bat               bat               NN
# bat               bat               bat               NN
# generally         gener             generally         RB
# recognised        recognis          recognised        VBN
# oldest            oldest            oldest            JJS
# bat               bat               bat               NN
# still             still             still             RB
# existence         exist             existence         RB
# dated             date              dated             JJ
# 1729              1729              1729              CD
# display           display           display           NN
# sandham           sandham           sandham           NN
# room              room              room              NN
# oval              oval              oval              JJ
# london            london            london            NN
# cricket           cricket           cricket           NN
# bat               bat               bat               NN
# specialised       specialis         specialised       VBD
# piece             piec              piece             JJ
# equipment         equip             equipment         NN
# used              use               used              VBN
# batsmen           batsmen           batsman           NNS
# sport             sport             sport             VBP
# cricket           cricket           cricket           NN
# hit               hit               hit               VBD
# ball              ball              ball              DT
# typically         typic             typically         RB
# consisting        consist           consisting        VBG
# cane              cane              cane              NN
# handle            handl             handle            NN
# attached          attach            attached          VBD
# flat-fronted      flat-front        flat-fronted      JJ
# willow-wood       willow-wood       willow-wood       NN
# blade             blade             blade             NN
# length            length            length            NN
# bat               bat               bat               NN
# may               may               may               MD
# 38                38                38                CD
# inches            inch              inch              NNS
# 965               965               965               CD
# mm                mm                mm                NNS
# width             width             width             JJ
# 4.25              4.25              4.25              CD
# inches            inch              inch              NNS
# 108               108               108               CD
# mm                mm                mm                NN
# use               use               use               NN
# first             first             first             RB
# mentioned         mention           mentioned         VBD
# 1624              1624              1624              CD

# %%
from collections import Counter

uniGram = Counter(tokens)
biGram = Counter(zip(tokens, tokens[1:]))

def calculate_probability(sentence, uniGram, biGram):
    output_probability = 1
    
    for word1, word2 in zip(sentence, sentence[1:]):
        probability = biGram[(word1, word2)] / uniGram[word1]
        output_probability *= probability
    
    return output_probability

# %%
from nltk import RegexpParser

chunker = RegexpParser("""
    NP: {<DT>?<JJ>*<NN>}
    P: {<IN>}
    V: {<V>.*}
    PP: {<p> <NP>}
    VP: {<V> <NP|PP>*}
""")

  
output = chunker.parse(pos_tags)
output.draw()
